# %% [markdown]
# ### LSA Experiment against newsgroup text dataset

# %%
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.datasets import fetch_20newsgroups

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /Users/asyam/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Selected the space newsgroup for my experiment
categories = ['sci.space']
dataset = fetch_20newsgroups(subset='all',shuffle=True, random_state=42, categories=categories)
corpus = dataset.data
corpus = [x.lower() for x in corpus]

# %% [markdown]
# ### TF-IDF Vectorization

# %%
corpus[0]
# Out:
# 'from: aws@iti.org (allen w. sherzer)\nsubject: re: orbital repairstation\norganization: evil geniuses for a better tomorrow\nlines: 20\n\nin article <c5hcbo.joy@zoo.toronto.edu> henry@zoo.toronto.edu (henry spencer) writes:\n\n>the biggest problem with this is that all orbits are not alike.  it can\n>actually be more expensive to reach a satellite from another orbit than\n>from the ground.  \n\nbut with cheaper fuel from space based sources it will be cheaper to \nreach more orbits than from the ground.\n\nalso remember, that the presence of a repair/supply facility adds value\nto the space around it. if you can put your satellite in an orbit where it\ncan be reached by a ready source of supply you can make it cheaper and gain\nbenefit from economies of scale.\n\n  allen\n-- \n+---------------------------------------------------------------------------+\n| lady astor:   "sir, if you were my husband i would poison your coffee!"   |\n| w. churchill: "madam, if you were my wife, i would drink it."             |\n+----------------------58 days to first flight of dcx-----------------------+\n'

# %%
stopset = set(stopwords.words('english'))
stopset.update(['18084tm','__','___','_____','acad3','access','added','af','afit','alaska','also','april','article','au','available','baalke','base','bbs','borden','ca','cacs','cain','caltech','claudio','cmu','com','command','could','cs','cso','daily','darling','david','dc','digest','digex','distribution','dseg','dublin','eder','edu','egalon','eng','enzo','fidonet','fnal','fnalf','forwarded','fraering','fred','free','gary','gehrels','gif','gothamcity','gov','government','henry','hst','ibm','ie','image','images','institute','international','ireland','isu','james ','jeff','jpl','jsc','ke4zv','kelvin','king','kjenks','larc','larrison ','lick','like','lines','loss','mankato','matthew ','mccall','mil','moon','msb','msu','msus','net','nicho','nsmca','ofa123','oh','oliveira','oort','org','organization','palmer','pat','pgf','phil','prb','raider','rborden','read','ron','ross','sci','sigurdsson','smiley','software','speak','spencer','sq','steinn','subject','sysmgr','tcd','temporary','test','ti','tkelso','topaz','toronto','ts','ucsc','uiuc','uk','umd','updated','usl','uvic','vacation','vax1','venari','via','victor','vnet','washington','would','wpi','wright','zoo',])

# %%
vectorizer = TfidfVectorizer(stop_words=stopset,
                                 use_idf=True, ngram_range=(1, 3))
X = vectorizer.fit_transform(corpus)

# %%
print(X[0])
# Out:
#   (0, 34185)	0.0498322212419
#   (0, 114771)	0.0494776232733
#   (0, 24011)	0.0872670364014
#   (0, 197853)	0.0481621165785
#   (0, 156675)	0.0392436656799
#   (0, 183531)	0.0727026934559
#   (0, 80901)	0.0536625361385
#   (0, 94730)	0.0559038066394
#   (0, 37638)	0.0326014427375
#   (0, 226766)	0.0526907149563
#   (0, 7952)	0.0349027842898
#   (0, 43542)	0.0804443835168
#   (0, 116335)	0.064961003395
#   (0, 246150)	0.0169840725169
#   (0, 38258)	0.0624687358625
#   (0, 172136)	0.0366402639184
#   (0, 157102)	0.102750416523
#   (0, 23947)	0.0804443835168
#   (0, 20641)	0.0361005986642
#   (0, 82156)	0.0447187301827
#   (0, 179660)	0.101938043517
#   (0, 190811)	0.0741831878493
#   (0, 26533)	0.0370915939246
#   (0, 156068)	0.0575770691298
#   (0, 99528)	0.084181062362
#   :	:
#   (0, 156478)	0.0804443835168
#   (0, 179765)	0.0804443835168
#   (0, 180068)	0.0804443835168
#   (0, 204486)	0.0804443835168
#   (0, 215807)	0.0804443835168
#   (0, 131390)	0.0804443835168
#   (0, 48600)	0.0804443835168
#   (0, 93330)	0.0804443835168
#   (0, 37263)	0.0804443835168
#   (0, 73741)	0.0804443835168
#   (0, 192196)	0.0804443835168
#   (0, 24037)	0.0572193133341
#   (0, 120259)	0.0565422031253
#   (0, 31214)	0.0565422031253
#   (0, 200583)	0.0565422031253
#   (0, 106960)	0.0565422031253
#   (0, 167288)	0.0565422031253
#   (0, 51146)	0.0565422031253
#   (0, 49228)	0.0565422031253
#   (0, 130157)	0.0565422031253
#   (0, 243532)	0.0759157851389
#   (0, 71499)	0.0759157851389
#   (0, 14770)	0.0759157851389
#   (0, 62914)	0.0552999353675
#   (0, 87644)	0.0552999353675

# %% [markdown]
# ### LSA

# %%
X.shape
# Out:
# (987, 249225)

# %%
# According to the documentation, for LSA, in case of n_components a value of 100 is recommended.
lsa = TruncatedSVD(n_components=100, n_iter=10)
lsa.fit(X)
# Out:
# TruncatedSVD(algorithm='randomized', n_components=100, n_iter=10,
#        random_state=None, tol=0.0)

# %%
lsa.components_[0]
# Out:
# array([ 0.0150963 ,  0.00078789,  0.00040133, ...,  0.00217403,
#         0.00217403,  0.00217403])

# %%
terms = vectorizer.get_feature_names()
for i, comp in enumerate(lsa.components_): 
    termsInComp = zip (terms,comp)
    sortedTerms =  sorted(termsInComp, key=lambda x: x[1], reverse=True) [:10]
    print("Concept %d:" % i )
    for term in sortedTerms:
        print(term[0])
    print (" ")
# Out:
# Concept 0:
# space
# nasa
# writes
# shuttle
# one
# orbit
# launch
# mission
# earth
# posting
#
# Concept 1:
# elements
# element
# shuttle
# air force technology
# force technology
# two line
# orbital
# current
# kelso
# element sets
#
# Concept 2:
# gene
# theporch
# billion
# gene theporch
# theporch gene
# reward
# year
# gene theporch gene
# first
# residents
#
# Concept 3:
# gamma
# energetic
# gamma ray
# ray
# bursters
# gamma ray bursters
# ray bursters
# big capacitor
# capacitor
# model
#
# Concept 4:
# sky
# night
# rights
# night sky
# vandalizing
# vandalizing sky
# george
# light
# canon
# george krumins
#
# Concept 5:
# mission
# servicing
# zoology
# boost
# arrays
# servicing mission
# shuttle
# mission scheduled
# sky
# 11 days
#
# Concept 6:
# kuiper
# space
# object
# nicoll
# uwo
# prism
# james
# belt object
# kuiper belt object
# kuiper belt
#
# Concept 7:
# higgins
# allen
# josh
# josh hopkins
# jbh55289
# jbh55289 uxa
# hopkins
# iti
# manned
# uxa
#
# Concept 8:
# kuiper
# object
# nicoll
# james
# uwo
# prism
# belt object
# kuiper belt object
# karla
# kuiper belt
#
# Concept 9:
# knox
# bby
# bond
# gregory bond
# gnb
# knox box
# gregory
# buckeridge
# buckeridge young
# burdett
#
# Concept 10:
# astronomy
# min
# per
# 0891
# 0891 88
# 48p
# tel 0891
# tel 0891 88
# astronomy space
# us
#
# Concept 11:
# zoology
# temperature
# utzoo
# collision zoology
# collision zoology svr3
# dick dunn
# dick dunn utzoo
# dunn utzoo
# high speed collision
# resembles high
#
# Concept 12:
# jupiter
# comet
# higgins
# pyron
# around jupiter
# orbit around jupiter
# orbit around
# skndiv
# around
# comet orbit
#
# Concept 13:
# pyron
# higgins
# skndiv
# pyron skndiv
# bill
# dillon pyron
# dillon
# habitable
# vax support
# 214
#
# Concept 14:
# station
# option
# space station
# redesign
# nasa
# energetic
# knox
# shafer
# mksol
# kuiper
#
# Concept 15:
# convex
# jupiter
# comet
# tom
# space space
# space space university
# original sender
# space university original
# university original
# university original sender
#
# Concept 16:
# higgins
# convex
# cloud
# george
# rights
# mechanism
# gamma
# gamma ray
# george krumins
# krumins
#
# Concept 17:
# convex
# convex computer
# boeing
# matthew
# nasa
# kuiper
# oz
# schumach
# gatech
# pyron
#
# Concept 18:
# convex
# convex computer
# boeing
# sky
# schumach
# user
# convex convex
# convex richard
# convex richard schumacher
# richard schumacher
#
# Concept 19:
# alphacdc
# scicom
# scicom alphacdc
# wats
# wats scicom
# wats scicom alphacdc
# bruce watson
# watson
# habitable
# bruce
#
# Concept 20:
# alphacdc
# scicom
# scicom alphacdc
# centaur
# proton
# wats
# wats scicom
# wats scicom alphacdc
# bruce watson
# watson
#
# Concept 21:
# alphacdc
# scicom
# scicom alphacdc
# wats
# wats scicom
# wats scicom alphacdc
# pyron
# bruce watson
# bruce
# watson
#
# Concept 22:
# matthew
# gatech
# uucp
# phantom
# phantom gatech
# oil
# ryukoku
# lunar
# pluto
# deluca
#
# Concept 23:
# mining
# aurora
# jupiter
# comet
# online communications
# luna
# express online
# express online communications
# express
# posting
#
# Concept 24:
# cook
# lunar
# srl02
# pyron
# station
# skndiv
# fuel
# qucdn
# qucdn queensu
# one
#
# Concept 25:
# nasa
# uucp
# qucdn
# qucdn queensu
# queensu
# coffman
# luna
# graydon
# lunar
# arrays
#
# Concept 26:
# cook
# srl02
# higgins
# sunrise
# sunset
# sunrise sunset times
# sunset times
# sunrise sunset
# ftcollinsco
# ftcollinsco ncr
#
# Concept 27:
# higgins
# arrays
# matthew
# habitable
# option
# station
# gatech
# bnr
# launch
# bill
#
# Concept 28:
# sunrise
# sunset
# sunrise sunset times
# sunset times
# sunrise sunset
# drexel
# times
# wetstein
# pearson
# cbis
#
# Concept 29:
# pluto
# higgins
# lunar
# solar system
# orbit
# system
# satellite
# sunrise
# sunset
# sunrise sunset times
#
# Concept 30:
# matthew
# launch
# gatech
# pluto
# sunrise
# sunset
# sunrise sunset times
# sunset times
# sunrise sunset
# internet
#
# Concept 31:
# arrays
# solar
# solar arrays
# design solar
# design solar arrays
# internet
# pluto
# stockton
# design
# space
#
# Concept 32:
# matthew
# gatech
# ryukoku
# phantom
# phantom gatech
# oil
# deluca
# matthew deluca
# matthew phantom
# matthew phantom gatech
#
# Concept 33:
# internet
# stockton
# resources
# internet resources
# vax003
# vax003 stockton
# stk1203
# stk1203 vax003
# stk1203 vax003 stockton
# higgins
#
# Concept 34:
# temperature
# turner
# cook
# stockton
# internet
# nasa
# indiana
# resources
# pluto
# internet resources
#
# Concept 35:
# higgins
# abomination
# field
# ucsu
# ucsu colorado
# already
# bright
# taste
# crary
# frank crary
#
# Concept 36:
# turner
# indiana
# lunar
# weather
# ir
# visual
# unocal
# astro indiana
# bigbang
# bigbang astro
#
# Concept 37:
# higgins
# bill
# pluto
# space program
# teflon
# term
# long
# long term
# ward
# program
#
# Concept 38:
# batse
# detectors
# positional
# shafer
# turner
# gsfc
# communications
# online communications
# express online
# express online communications
#
# Concept 39:
# orion
# prototype
# film
# sfu
# turner
# work
# indiana
# zoology
# leigh
# cook
#
# Concept 40:
# shafer
# wings
# rigel dfrf
# rigel dfrf nasa
# dfrf nasa
# dfrf
# rigel
# flb
# higgins
# shafer rigel
#
# Concept 41:
# pluto
# shuttle program office
# space shuttle program
# shuttle program
# program office
# gm2
# gm2 space
# gm2 space shuttle
# nasa gm2
# nasa gm2 space
#
# Concept 42:
# princeton
# jemison
# star trek
# trek
# doug
# star
# transporter operator
# fs7
# fs7 ece
# phoenix
#
# Concept 43:
# turner
# indiana
# accelerations
# ir
# visual
# weather
# unocal
# comet
# astro indiana
# bigbang
#
# Concept 44:
# accelerations
# 45g
# acceleration
# amruth
# amruth laxman
# laxman
# globe
# shafer
# xpresso
# manned
#
# Concept 45:
# orion
# film
# pluto
# prototype
# flb
# sfu
# accelerations
# baube
# comet
# leigh
#
# Concept 46:
# timer
# galileo
# jemison
# bnr
# star trek
# trek
# princeton
# op
# transporter operator
# star
#
# Concept 47:
# accelerations
# 45g
# temperature
# acceleration
# amruth
# amruth laxman
# laxman
# timer
# lan
# galileo
#
# Concept 48:
# timer
# bnr
# galileo
# otago
# aurora
# op
# otago ac
# otago ac nz
# nz
# ac nz
#
# Concept 49:
# otago
# otago ac
# otago ac nz
# ac nz
# nz
# ac
# bill
# globe
# dietz
# quotation
#
# Concept 50:
# dietz
# rochester
# calpoly
# spacecraft
# steinly
# paul
# dietz rochester
# solar
# power
# paul dietz
#
# Concept 51:
# dietz
# rochester
# steinly
# paul
# dietz rochester
# paul dietz
# manned lunar exploration
# lunar exploration
# manned lunar
# crystal city
#
# Concept 52:
# comet
# dietz
# nasa
# prize
# orbit
# rochester
# mancus
# backers
# lindbergh
# pluto
#
# Concept 53:
# nicholls
# greg
# drag
# berkeley
# otago
# news ureply
# ureply
# poster views news
# views news
# views news ureply
#
# Concept 54:
# comet
# launch
# ncsu
# wrench
# tool
# eos
# eos ncsu
# jmcocker
# dietz
# rochester
#
# Concept 55:
# mars
# launch
# face
# schiewer
# inland
# flb
# pa881a
# baube
# etrat
# error
#
# Concept 56:
# magnetic field
# magnetic
# berkeley
# dragless
# etrat
# field
# bothering
# error
# sorry
# caution
#
# Concept 57:
# magnetic field
# magnetic
# field
# dragless
# wrench
# caste
# prize
# tool
# eos
# ncsu
#
# Concept 58:
# magnetic field
# magnetic
# field
# comet
# berkeley
# drag
# dragless
# dragless satellite
# earth magnetic
# earth magnetic field
#
# Concept 59:
# globe
# bill
# xpresso
# space
# uucp bill
# xpresso uucp
# xpresso uucp bill
# nasa
# calpoly
# center
#
# Concept 60:
# solid state
# tube
# nasa
# tubes
# state
# solid
# better
# lower
# uwo
# transistors
#
# Concept 61:
# comet
# solid state
# prize
# solid
# tube
# lower
# uwo
# station
# state
# tubes
#
# Concept 62:
# station
# redesign
# space station
# russian
# zoology
# shea
# level
# committee
# overhead
# gibbons
#
# Concept 63:
# rockets
# rocketry
# 50
# dokas
# flight
# rocket
# faa
# 50 000 feet
# 50 000
# 000 feet
#
# Concept 64:
# comet
# space
# emr
# geod
# geod emr
# mancus
# newsgroup
# level
# orbit
# colostate
#
# Concept 65:
# rockets
# mars
# face
# schiewer
# inland
# aurora
# pa881a
# comet
# pa881a inland
# rocketry
#
# Concept 66:
# rights
# face
# life
# schiewer
# mars
# inland
# pa881a
# pa881a inland
# timer
# life mars
#
# Concept 67:
# xpresso
# globe
# lindbergh
# backers
# princeton
# bill
# shakala
# large
# uucp bill
# xpresso uucp
#
# Concept 68:
# rockwell
# munizb
# rwtms2
# munizb rwtms2
# munizb rwtms2 decnet
# rwtms2 decnet
# power
# power system
# decnet
# lps
#
# Concept 69:
# colostate
# level
# wallacen
# wallacen colostate
# emr
# geod
# geod emr
# stephens
# nathan
# nathan wallace
#
# Concept 70:
# level
# process
# station
# wingert
# mars
# colostate
# rights
# shuttle
# face
# cohen
#
# Concept 71:
# nasa
# pluto
# field
# shadow
# light
# charon
# magnetic field
# magnetic
# pluto charon
# princeton
#
# Concept 72:
# dong
# light
# bruce
# tesla
# time
# launch
# shakala
# dong dong
# existence
# station
#
# Concept 73:
# colostate
# wallacen
# wallacen colostate
# nathan
# nathan wallace
# wallace
# berkeley
# space
# ancient
# rockets
#
# Concept 74:
# colostate
# wallacen
# wallacen colostate
# dong
# bruce
# overhead
# bruce scott
# nathan
# nathan wallace
# wallace
#
# Concept 75:
# dong
# berkeley
# face
# bruce scott
# bruce
# schiewer
# yamauchi
# scott
# overhead
# inland
#
# Concept 76:
# berkeley
# violet berkeley
# violet
# sail
# taste
# food
# solar sail
# ghelf
# ghelf violet
# ghelf violet berkeley
#
# Concept 77:
# shakala
# berkeley
# colostate
# titan
# wallacen
# wallacen colostate
# charlie prael
# dante
# dante shakala
# prael
#
# Concept 78:
# emr
# geod
# geod emr
# ether
# stephens
# dave stephenson
# stephens geod
# stephens geod emr
# stephenson
# pluto
#
# Concept 79:
# shakala
# shadow
# charon
# ics uci
# uci
# ics
# incoming
# pluto charon
# pluto
# colostate
#
# Concept 80:
# clarke
# ether
# cohen
# launch
# keithley
# colostate
# indyvax
# university
# ucf
# acme ucf
#
# Concept 81:
# ics uci
# ics
# uci
# incoming
# ics uci incoming
# uci incoming
# colostate
# berkeley
# wallacen
# wallacen colostate
#
# Concept 82:
# cohen
# berkeley
# rights
# single launch
# emr
# geod
# geod emr
# mdc
# andy
# sail
#
# Concept 83:
# colostate
# wallacen
# wallacen colostate
# abomination
# nathan
# nathan wallace
# wallace
# overhead
# courtney
# tom courtney
#
# Concept 84:
# clarke
# ucf
# acme ucf
# clarke acme
# clarke acme ucf
# thomas clarke
# 407 658
# university central
# acme
# 658
#
# Concept 85:
# cray
# bobo
# colostate
# dietz
# thejester
# thejester cray
# deseases
# ac
# wallacen
# wallacen colostate
#
# Concept 86:
# detectors
# rays
# uchicago
# graydon
# dan
# burst
# cosmic rays
# gamma
# ryukoku
# abomination
#
# Concept 87:
# clarke
# colostate
# wallacen
# wallacen colostate
# ucf
# acme ucf
# clarke acme
# clarke acme ucf
# thomas clarke
# acme
#
# Concept 88:
# space
# desire
# may
# zoology
# sky
# beauty
# netcom
# astro
# uow
# marketing
#
# Concept 89:
# thruster
# ics uci
# shakala
# bobo
# uci
# cray
# ics
# incoming
# ics uci incoming
# uci incoming
#
# Concept 90:
# cray
# magellan
# caste
# bobo
# thejester
# thejester cray
# oms
# deseases
# oms fuel
# steinly
#
# Concept 91:
# ics uci
# uci
# ics
# incoming
# ics uci incoming
# uci incoming
# berkeley
# food
# violet berkeley
# taste
#
# Concept 92:
# shakala
# degrees
# cray
# sequence
# ac
# space 1999
# antenna
# performed
# real time
# rra
#
# Concept 93:
# ics uci
# uci
# ics
# incoming
# ics uci incoming
# uci incoming
# liquid
# cray
# liquids
# bobo
#
# Concept 94:
# detectors
# thruster
# sky
# uchicago
# caste
# keithley
# field
# probes
# mother
# mother ship
#
# Concept 95:
# dgi
# jennise
# opus
# opus dgi
# boeing
# steinly
# usa nntp
# usa nntp posting
# spacecraft
# dgi milady
#
# Concept 96:
# space 1999
# 1999
# griffin
# weightlessness
# energy
# gamma
# drag
# motion
# probes
# doppelganger
#
# Concept 97:
# dgi
# jennise
# breathing
# spacecraft
# opus
# opus dgi
# gas
# ics uci
# uci
# incoming
#
# Concept 98:
# dgi
# jennise
# opus
# opus dgi
# dgi milady
# dgi milady printcap
# dynamic graphics
# dynamic graphics inc
# goddess
# goddess peripherals
#
# Concept 99:
# den
# den mmc
# mmc
# starfighter
# starfighter den
# starfighter den mmc
# griffin
# breathing
# retrieving
# caged
