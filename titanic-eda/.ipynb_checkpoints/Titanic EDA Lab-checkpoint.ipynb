# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv("data/train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %% [markdown]
# ### Perform EDA
#
# <li>Is the variable categorical or continuous?
#
# <li>Are there missing values?
#
# <li>Min, Max, Mean, and Standard Deviation of the continuous variables.
#
# <li>Histograms describing the distribution of the variable.

# %% [markdown]
# ### EDA on PassengerId

# %%
df.PassengerId.value_counts()
# Out:
# 891    1
# 293    1
# 304    1
# 303    1
# 302    1
# 301    1
# 300    1
# 299    1
# 298    1
# 297    1
# 296    1
# 295    1
# 294    1
# 292    1
# 306    1
# 291    1
# 290    1
# 289    1
# 288    1
# 287    1
# 286    1
# 285    1
# 284    1
# 283    1
# 282    1
# 281    1
# 305    1
# 307    1
# 279    1
# 321    1
#       ..
# 561    1
# 560    1
# 584    1
# 585    1
# 586    1
# 587    1
# 610    1
# 609    1
# 608    1
# 607    1
# 606    1
# 605    1
# 604    1
# 603    1
# 602    1
# 601    1
# 600    1
# 599    1
# 598    1
# 597    1
# 596    1
# 595    1
# 594    1
# 593    1
# 592    1
# 591    1
# 590    1
# 589    1
# 588    1
# 1      1
# Name: PassengerId, dtype: int64

# %% [markdown]
# **1) PassengerId is a continuous variable**

# %%
df.PassengerId.describe()
# Out:
# count    891.000000
# mean     446.000000
# std      257.353842
# min        1.000000
# 25%      223.500000
# 50%      446.000000
# 75%      668.500000
# max      891.000000
# Name: PassengerId, dtype: float64

# %% [markdown]
#  **2) min = 1, max = 891, mean = 446, standard deviation = 257.353842**

# %%
df[df.PassengerId.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# **3) There's no missing value**

# %%
df.PassengerId.hist()

# %% [markdown]
# **4) Histogram shows a very even distribution**

# %% [markdown]
# ### EDA on Survived

# %%
df.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# **1) Survived is a categorical variable**

# %% [markdown]
# **2) Categories are 0 and 1**

# %%
df[df.Survived.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# **3) There's no missing value**

# %%
df.Survived.value_counts().plot(kind='bar')

# %% [markdown]
# **4) Histogram shows that roughly 1/3 of the passengers survivided**

# %% [markdown]
# ## EDA on Pclass

# %%
df.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %% [markdown]
# **1) Pclass is a categorical variable**

# %% [markdown]
# **2) Categories are 1, 2 and 3**

# %%
df[df.Pclass.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# **3) There's no missing value**

# %%
df.Pclass.value_counts().plot(kind='bar')

# %% [markdown]
# **4) Histogram shows that more than half of the passengers were in class 3. The other half is almost divided equally between class 1 and 2 with class 1 having a few more than class 2.**

# %% [markdown]
# ## EDA on Sex

# %%
df.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %% [markdown]
# **1) Sex is a categorical variable**

# %% [markdown]
# **2) Categories are male and female**

# %%
df[df.Sex.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# **3) There's no missing value**

# %%
df.Cabin.hist()

# %% [markdown]
# ** 4) Histogram shows there were more male passengers than female passangers (almost 2X)**

# %% [markdown]
# ## EDA on  Age

# %%
df.Age.value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 30.00    25
# 28.00    25
# 21.00    24
# 25.00    23
# 36.00    22
# 29.00    20
# 32.00    18
# 27.00    18
# 35.00    18
# 26.00    18
# 16.00    17
# 31.00    17
# 20.00    15
# 33.00    15
# 23.00    15
# 34.00    15
# 39.00    14
# 17.00    13
# 42.00    13
# 40.00    13
# 45.00    12
# 38.00    11
# 50.00    10
# 2.00     10
# 4.00     10
# 47.00     9
#          ..
# 71.00     2
# 59.00     2
# 63.00     2
# 0.83      2
# 30.50     2
# 70.00     2
# 57.00     2
# 0.75      2
# 13.00     2
# 10.00     2
# 64.00     2
# 40.50     2
# 32.50     2
# 45.50     2
# 20.50     1
# 24.50     1
# 0.67      1
# 14.50     1
# 0.92      1
# 74.00     1
# 34.50     1
# 80.00     1
# 12.00     1
# 36.50     1
# 53.00     1
# 55.50     1
# 70.50     1
# 66.00     1
# 23.50     1
# 0.42      1
# Name: Age, dtype: int64

# %% [markdown]
# **1) Age is a continuous variable**

# %%
df.Age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %% [markdown]
# ** 2) min = 0.42, max = 80, mean = 29.699118, standard deviation = 14.526497 **

# %%
df[df.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %% [markdown]
# ** There are 177 missing values for Age **

# %%
df.Age.hist()

# %% [markdown]
# ** 4) Histogram shows that most people were between age 18 to 40 **

# %% [markdown]
# ## EDA on SibSp

# %%
df.SibSp.value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %% [markdown]
# ** 1) Although it looks like a categorical variable, this variable denotes number of Siblings/Spouses Aboard which by defnition a continuous variable. Although the chance of having more than 8 is really low but not impossible. We can probably treat it as categorical where the last category is for value 5 or more. **

# %%
df.SibSp.describe()
# Out:
# count    891.000000
# mean       0.523008
# std        1.102743
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        8.000000
# Name: SibSp, dtype: float64

# %% [markdown]
# ** 2) min = 0, max = 8, mean = 0.523008, standard deviation = 1.102743 **

# %%
df[df.SibSp.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# ** 3) There's no missing value **

# %%
df.SibSp.hist()

# %% [markdown]
# ** 4) According to the histogram most people have 0 sibling or spouse onboard. People with 1 sibling or spouse is the next largest. Very few of them had 2 or more siblings or spouses aboard. **

# %% [markdown]
# ## EDA on Parch

# %%
df.Parch.value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %% [markdown]
# ** 1) Similar to SibSp, this is by definition a continuous variable as it denotes number of Parents/Children aboard. However, the chance of having more than 6 parents/children is really low but possible. We can probably treat it as categorical where the last category is for value 6 or more. **

# %%
df.Parch.describe()
# Out:
# count    891.000000
# mean       0.381594
# std        0.806057
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        6.000000
# Name: Parch, dtype: float64

# %% [markdown]
# ** 2) min = 0, max = 6, mean = 0.381594, standard deviation = 0.806057 **

# %%
df[df.Parch.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# ** 3) There's no missing value **

# %%
df.Parch.hist()

# %% [markdown]
# ** According to the histogram most people did not have any parent or children aboard. Next is passengers 1 or 2 parent/children. **

# %% [markdown]
# ## EDA on Ticket

# %%
df.Ticket.value_counts()
# Out:
# 1601                7
# 347082              7
# CA. 2343            7
# CA 2144             6
# 347088              6
# 3101295             6
# S.O.C. 14879        5
# 382652              5
# 347077              4
# 113781              4
# 19950               4
# W./C. 6608          4
# 17421               4
# 349909              4
# 2666                4
# 113760              4
# PC 17757            4
# 4133                4
# LINE                4
# F.C.C. 13529        3
# 29106               3
# PC 17760            3
# 24160               3
# 371110              3
# 363291              3
# C.A. 34651          3
# PC 17755            3
# PC 17572            3
# C.A. 31921          3
# 239853              3
#                    ..
# 348123              1
# SC/PARIS 2146       1
# 349256              1
# SOTON/OQ 3101316    1
# 112053              1
# 29103               1
# 237668              1
# 330979              1
# A.5. 11206          1
# 28425               1
# ...

# %% [markdown]
# ** 1) This is a little confusing. Some values like *LINE* look categorical (or in other words discrete). Some other numerical values seem to be continuous. I think it's safe to consider Ticket number to be categorical. However, we might need to clean the data before using it **

# %%
df.Ticket.describe()
# Out:
# count      891
# unique     681
# top       1601
# freq         7
# Name: Ticket, dtype: object

# %% [markdown]
# ** 2) There are 681 unique categories **

# %%
df[df.Ticket.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# ** 3) There is no missing value **

# %%
df.Ticket.value_counts().plot(kind='bar')

# %% [markdown]
# ** 4) The histogram looks a little messy, as there are 681 unique categories. From the histogram, we can see that most of the ticket numbers are assigned to 1 single passenger. **

# %% [markdown]
# ## EDA on Fare

# %%
df.Fare.value_counts()
# Out:
# 8.0500      43
# 13.0000     42
# 7.8958      38
# 7.7500      34
# 26.0000     31
# 10.5000     24
# 7.9250      18
# 7.7750      16
# 26.5500     15
# 0.0000      15
# 7.2292      15
# 7.8542      13
# 8.6625      13
# 7.2500      13
# 7.2250      12
# 16.1000      9
# 9.5000       9
# 24.1500      8
# 15.5000      8
# 56.4958      7
# 52.0000      7
# 14.5000      7
# 14.4542      7
# 69.5500      7
# 7.0500       7
# 31.2750      7
# 46.9000      6
# 30.0000      6
# 7.7958       6
# 39.6875      6
#             ..
# 7.1417       1
# 42.4000      1
# 211.5000     1
# 12.2750      1
# 61.1750      1
# 8.4333       1
# 51.4792      1
# 7.8875       1
# 8.6833       1
# 7.5208       1
# 34.6542      1
# 28.7125      1
# 25.5875      1
# 7.7292       1
# 12.2875      1
# 8.6542       1
# 8.7125       1
# 61.3792      1
# 6.9500       1
# 9.8417       1
# 8.3000       1
# 13.7917      1
# 9.4750       1
# 13.4167      1
# 26.3875      1
# 8.4583       1
# 9.8375       1
# ...

# %% [markdown]
# ** 1) Fare is a continuous variable **

# %%
df.Fare.describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %% [markdown]
# ** 2) min = 0, max = 512.3292, mean = 32.204208, standard deviation = 49.693429 **

# %%
df[df.Fare.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# ** 3) There is no missing value **

# %%
df.Fare.hist()

# %% [markdown]
# ** 4) Most of the people paid in between 0 to 50 dollars. The highest price which is around 500 seems to be paid by only one passenger. **

# %% [markdown]
# ## EDA on Cabin

# %%
df.Cabin.value_counts()
# Out:
# C23 C25 C27    4
# G6             4
# B96 B98        4
# F2             3
# C22 C26        3
# E101           3
# D              3
# F33            3
# B22            2
# B49            2
# C65            2
# C125           2
# C78            2
# E121           2
# C124           2
# C123           2
# D20            2
# C68            2
# E67            2
# F G73          2
# B18            2
# B5             2
# C83            2
# C52            2
# E24            2
# C2             2
# E33            2
# E44            2
# B35            2
# F4             2
#               ..
# D21            1
# D56            1
# A5             1
# C30            1
# A19            1
# C90            1
# E68            1
# A23            1
# E40            1
# D15            1
# B102           1
# A10            1
# D48            1
# D49            1
# B50            1
# C99            1
# F38            1
# E49            1
# F G63          1
# D45            1
# B30            1
# ...

# %% [markdown]
# ** 1) Cabin is categorical **

# %%
df.Cabin.describe()
# Out:
# count             204
# unique            147
# top       C23 C25 C27
# freq                4
# Name: Cabin, dtype: object

# %% [markdown]
# ** 2) There are 147 unique categories **

# %%
df[df.Cabin.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 30            31         0       1
# 32            33         1       3
# 33            34         0       2
# ...

# %% [markdown]
# ** 3) There are 687 missing values for Cabin which is a lot. It almost adds up to number of class 2 and 3 passengers. May be those passengers were not given a cabin. **

# %%
df.Cabin.value_counts().plot(kind='bar')

# %% [markdown]
# ** 4) From the histogram it looks like most of the cabin was give to single passenger. Some were shared by 2 passengers. **

# %% [markdown]
# ## EDA on Embarked

# %%
df.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %% [markdown]
# ** 1) Embarked is categorical **

# %% [markdown]
# ** 2) There are three categories: S, C and Q. (C = Cherbourg; Q = Queenstown; S = Southampton) **

# %%
df[df.Embarked.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %% [markdown]
# ** 3) There are only 2 missing values. **

# %%
df.Embarked.value_counts().plot(kind='bar')

# %% [markdown]
# ** 4) The histogram shows that the port of embarkation for most passengers were Southampton. Around 170 people emarked from Cherbourg and around 80 from Queenstown. **

# %% [markdown]
# ## Exploration to see if there's any relationship between passenger class and survival

# %%
df[df.Pclass==1].Survived.value_counts().plot(kind='bar')

# %%
df[df.Pclass==2].Survived.value_counts().plot(kind='bar')

# %%
df[df.Pclass==3].Survived.value_counts().plot(kind='bar')

# %% [markdown]
# ** Surivival rate is highest for the first class passengers, around 2/3 survived. **

# %% [markdown]
# ** For class 2, survived vs died ratio is almost 50:50. **

# %% [markdown]
# ** Unfortunately, for the third class passengers, only around 20% survived **
